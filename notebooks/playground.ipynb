# %%
import pandas as pd
import dataclasses
from dataclasses import dataclass
import json
from kafka import KafkaProducer
from models import Ride, ride_from_row, ride_serializer

# %%
url='https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-11.parquet'

# %%
columns = ['PULocationID', 'DOLocationID', 'trip_distance', 'total_amount', 'tpep_pickup_datetime']
df = pd.read_parquet(url, columns=columns).head(1000)

# %%
df.iloc[0]
# Out:
# PULocationID                             43
# DOLocationID                            186
# trip_distance                          1.68
# total_amount                          22.15
# tpep_pickup_datetime    2025-11-01 00:13:25
# Name: 0, dtype: object

# %%
ride = ride_from_row(df.iloc[0])

# %%
ride_dict = dataclasses.asdict(ride)

# %%
(ride_dict)
# Out:
# {'PULocationID': 43,
#  'DOLocationID': 186,
#  'trip_distance': 1.68,
#  'total_amount': 22.15,
#  'tpep_pickup_datetime': 1761956005000}

# %%
type(json.dumps(ride_dict))
# Out:
# str

# %%
json.dumps(ride_dict)
# Out:
# '{"PULocationID": 43, "DOLocationID": 186, "trip_distance": 1.68, "total_amount": 22.15, "tpep_pickup_datetime": 1761956005000}'

# %%
json.dumps(ride_dict).encode('utf-8')
# Out:
# b'{"PULocationID": 43, "DOLocationID": 186, "trip_distance": 1.68, "total_amount": 22.15, "tpep_pickup_datetime": 1761956005000}'

# %%
type(json.dumps(ride_dict).encode('utf-8'))
# Out:
# bytes
